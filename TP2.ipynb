# %% [markdown]
# ### 1. Princípios de Criação de Prompts Eficazes

# %% [markdown]
# **Enunciado**: Alguns princípios são essenciais para a construção de prompts claros e obtenção de respostas precisas. Identifique e explique quais princípios foram utilizados no prompt abaixo:
#
# Prompt
#
# Como um especialista em turismo, liste 3 atrações turísticas imperdíveis de Paris e forneça uma breve descrição para cada uma delas. Aqui está um exemplo do formato esperado:
#
# ---
#
# Atração 1: Torre Eiffel
#
# Descrição: Um dos monumentos mais icônicos do mundo, conhecido por sua estrutura de ferro e vista panorâmica da cidade.

# %% [markdown]
# **R.:**
#
# 1. Exemplo de resultado esperado, aumentando as chances do modelo gerar o resultado no formato desejado
# 2. Definição de papeis/função, influenciando na forma como a resposta será construída para que se assemelhe ao contexto do papel passado para o modelo
# 3. Instruções claras e objetivas, a tarefa a ser executa está muito bem delimitada e objetiva, evitando ambiguidades e alucinações do modelo

# %% [markdown]
# ### 2. Simulação de Atendimento ao Cliente com Diferentes Personas

# %% [markdown]
# **Enunciado:** Vamos simular uma situação de telemarketing onde persona e tom são críticos para o sucesso da interação. Para criarmos uma base de treinamento dos operadores, simule duas respostas para o mesmo atendimento, ora com um cliente agressivo, ora com um cliente tranquilo. Crie e teste um prompt (Poe.com) para cada situação a partir do atendimento:
#
#     “Bom dia, me chamo João e lhe trago hoje uma promoção imperdível sobre a sua assinatura de internet móvel. Por mais 20 reais, consigo lhe oferecer 10GB a mais na sua franquia. Quando podemos estar agendando a sua migração?”
#
# Descreva o comportamento do cliente nas duas situações? As respostas saíram como o esperado?

# %% [markdown]
# **R.:** O cliente agressivo rejeitou imediatamente a oferta e reclamou quanto aos contatos indesejáveis, já o cliente tranquilo foi mais cordial e disse que iria considerar a oferta.
#
# As respostas foram adequadas ao prompts passado.

# %% [markdown]
# Cliente agressivo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Cliente tranquilo
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Automação de Mensagens Promocionais com Princípios de Prompting

# %% [markdown]
# **Enunciado:** A empresa de turismo viagens.com deseja automatizar o processo de criação de envio de mensagens para clientes, informando-lhes sobre promoções recentes. Escreva um prompt que contenha os três princípios de 1) persona, 2) dados e 3) tom para gerar a mensagem automática. Execute o prompt usando a sua conta Poe.com e justifique se o LLM respondeu como esperado.

# %% [markdown]
# **R.:** Usando o prompt "Você é um agente de viagens e está preparando mensagens que serão enviadas aos clientes informando-lhes sobre promoções. Use um tom cativante e envolvente para criar as mensagens. Crie 3 mensagens usando o Rio de Janeiro como cidade referência para as promoções" o LLM respondeu como o esperado.
#
# Persona: Agente de viagens
#
# Dados: 3 mensanges e Rio de Janeiro
#
# Tom: Cativante e envolvente

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.  Desenvolvimento de Prompts para Recomendação de Produtos

# %% [markdown]
# **Enunciado:** Você está desenvolvendo um sistema de recomendações de produtos para um e-commerce. Crie dois prompts com base nos princípios de prompting, sendo o primeiro um prompt simples e o segundo um prompt com exemplos (few-shot prompting). Utilize o Poe.com para testar os prompts com um LLM, comparando os resultados gerados. Qual dos prompts foi mais eficaz e por quê?

# %% [markdown]
# **R.:** O prompt com exemplos de quais produtos seriam recomendados foi mais eficaz, pois a resposta já continha todo o direcionamento para se começar a desenvolver um sistema de recomendações, enquanto que o prompt simples o LLM pediu por mais detalhes para poder ajudar.

# %% [markdown]
# Prompt simples
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Prompt com exemplos
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 5. Listagem de Componentes de Computadores de Alto Desempenho

# %% [markdown]
# **Enunciado:** Utilize o Poe.com para criar um prompt simples que faça o LLM listar os principais componentes de um computador de alto desempenho, suas capacidades computacionais (HD, RAM, CPU, GPU…), marcas, modelos e preços. Teste o prompt e explique se o resultado atendeu às expectativas: as marcas e modelos existem? As capacidades do computador são de alto desempenho? Compare com fontes encontradas na internet.

# %% [markdown]
# **R.:** Com o GPT-4o o resultado foi satisfatório, as marcas e modelos existem e são de alto desempenho, enquanto que o Claude pegou peças mais antigas, mas ainda assim de bom desempenho.

# %% [markdown]
# GPT-4o
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Claude-3-Haiku
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 6. Análise dos Benefícios da Inteligência Artificial para Pequenas Empresas

# %% [markdown]
# **Enunciado:** Desenvolva um prompt simples para que o LLM forneça uma análise rápida sobre os benefícios de usar inteligência artificial em pequenas empresas. Qual foi o resultado gerado pelo LLM? Aplique os princípios de prompt para obter resultados mais precisos. Teste os prompts na sua conta do Poe.com e copie os prompts e respectivas saídas, junto com a explicação do que foi feito entre um prompt e outro.

# %% [markdown]
# **R.:** Resultados gerados por cada iteração:
# 1. Prompt simples: O LLM gerou um texto abrangente sobre tudo que a IA poderia fazer pela pequeno negócio
# 2. Prompt com especificidade do ramo da empresa: O texto gerado foi mais direcionado e aderente ao ramo da empresa
# 3. Prompt com mais especificidade e exemplos de aplicação da IA na empresa: O resultado foi mais preciso e direcionado

# %% [markdown]
# 1º Prompt
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2º Prompt
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 3º Prompt
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 7. Resumo de Notícia Utilizando Exemplos em Prompts

# %% [markdown]
# Usando a API Gemini, crie um notebook que utilize prompts para resumir uma notícia (escolha da página principal de um portal de notícias e copie no notebook). O prompt deve solicitar um resumo dessa notícia usando o princípio de Exemplos para guiar a resposta do LLM. Teste o código e avalie a qualidade do resumo gerado.

# %%
#pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import google.generativeai as genai
import os
from google.generativeai.types import HarmCategory, HarmBlockThreshold
import datetime as dt
#import tqdm as notebook_tqdm

data_coleta = dt.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

urls = ['https://ge.globo.com/basquete/nba/noticia/2024/11/09/lebron-da-assistencia-incrivel-de-costas-e-faz-mais-um-triplo-duplo-em-vitoria-dos-lakers-veja-lance.ghtml',
        'https://ge.globo.com/futebol/times/flamengo/noticia/2024/11/09/escalacao-do-flamengo-ensaios-antes-da-decisao-deixam-duvida-entre-bruno-henrique-e-michael.ghtml',
        'https://ge.globo.com/ms/noticia/2024/11/09/aos-50-anos-medalhista-olimpica-em-atenas-e-pequim-disputa-artilharia-em-estadual.ghtml']

genai.configure(api_key=os.environ["GEMINI_KEY"])

system_instruction = '''
    Baseado no seguinte exemplo:
    
    URL: https://ge.globo.com/volei-de-praia/noticia/2024/11/09/suecos-inovam-no-volei-de-praia-com-tecnica-que-rendeu-ouro-olimpico.ghtml

    Resumo: Jogadores suecos inovam no vôlei de praia com técnica que rendeu ouro olímpico o Swedish Jump Set. 
    A técnica é um movimento no qual o jogador salta como se fosse cravar a bola no lado do oponente, mas, em vez disso, escolhe se vai devolver a 
    bola para seu parceiro ou atacar tendo realizado apenas dois toques.
    
    Resuma a próxima notícia em 50 palavras ou menos: '''

safety_settings={
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
}

generation_config = genai.types.GenerationConfig(
        candidate_count=1,
        max_output_tokens=500,
        temperature=0.0,
    )

model = genai.GenerativeModel("gemini-1.5-flash"
                              ,system_instruction = system_instruction
                              ,safety_settings=safety_settings
                              ,generation_config=generation_config)

print(data_coleta)
for url in urls:
    response = model.generate_content(url)
    print(response.text.strip())
# Out:
# 2024-11-10 11:33:14
# LeBron James, do Los Angeles Lakers, fez mais um triplo-duplo, incluindo uma assistência de costas espetacular, que ajudou a equipe a vencer a partida. O lance, que viralizou nas redes sociais, mostra a habilidade e a visão de jogo do astro do basquete.
# O Flamengo enfrenta um dilema para a decisão: Bruno Henrique ou Michael? O técnico ainda não definiu o titular, e os ensaios deixam a dúvida no ar. A escalação do Mengão para o jogo decisivo será divulgada em breve.
# Aos 50 anos, a medalhista olímpica em Atenas e Pequim, Ana Paula, disputa a artilharia do Campeonato Estadual de Futebol Feminino de Mato Grosso do Sul. A veterana, que joga pelo Operário, busca manter o ritmo competitivo e inspirar as novas gerações.

# %% [markdown]
# **R.:** Os resumos apresentaram algumas falhas, como informações inventadas para a terceira url, que varia entre inventar o time da Atleta ou trocar o seu nome.

# %% [markdown]
# ### 8. Identificação de Entidades em Notícias com LLM
#
# Uma consultoria lhe contratou para automatizar a descoberta de pessoas mencionadas em notícias de jornal. Com base no Exercício 7, escolha 3 notícias e monte uma aplicação com um prompt para o LLM identificar menções a diferentes entidades em cada notícia (como pessoas, órgãos públicos, empresas…). Implemente um notebook para testar o código usando a API do Gemini. Descreva o prompt, seus resultados e avalie se a resposta do modelo atende às expectativas da consultoria.

# %%
import google.generativeai as genai
import os
from google.generativeai.types import HarmCategory, HarmBlockThreshold
import datetime as dt

data_coleta = dt.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

urls = ['https://ge.globo.com/basquete/nba/noticia/2024/11/09/lebron-da-assistencia-incrivel-de-costas-e-faz-mais-um-triplo-duplo-em-vitoria-dos-lakers-veja-lance.ghtml',
        'https://ge.globo.com/futebol/times/flamengo/noticia/2024/11/09/escalacao-do-flamengo-ensaios-antes-da-decisao-deixam-duvida-entre-bruno-henrique-e-michael.ghtml',
        'https://ge.globo.com/volei-de-praia/noticia/2024/11/09/suecos-inovam-no-volei-de-praia-com-tecnica-que-rendeu-ouro-olimpico.ghtml'
        ]

genai.configure(api_key=os.environ["GEMINI_KEY"])

system_instruction = '''
    Baseado no seguinte exemplo:
    
    URL: https://ge.globo.com/ms/noticia/2024/11/09/aos-50-anos-medalhista-olimpica-em-atenas-e-pequim-disputa-artilharia-em-estadual.ghtml

    Entidades envolvidas: 
        - Tânia Maranhão : Jogadora de Futebol
        - Operário : Time de futebol
        - César Fuscão : Técnico do Operário
        - Cefac : Time de futebol
        - Ana Jéssica : Jogadora de Futebol
        - Aline : Jogadora de Futebol
        - Brenda : Jogadora de Futebol

    Entre na seguinte url e identifique as entidades envolvidas: '''

safety_settings={
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
}

generation_config = genai.types.GenerationConfig(
        candidate_count=1,
        max_output_tokens=500,
        temperature=0.9,
    )

model = genai.GenerativeModel('gemini-1.5-pro'#"gemini-1.5-flash"
                              ,system_instruction = system_instruction
                              ,safety_settings=safety_settings
                              ,generation_config=generation_config)

print(data_coleta)
for url in urls:
    response = model.generate_content(url)
    print(response.text.strip())
    print()
# Out:
# 2024-11-10 11:33:54
# Entidades envolvidas na URL fornecida:
#
# * **LeBron James:** Jogador dos Lakers. É o foco principal da notícia, devido à assistência "incrível" e ao triplo-duplo.
# * **Los Angeles Lakers:** Time de basquete da NBA. Time para o qual LeBron James joga.
# * **Anthony Davis:** Jogador dos Lakers.  Mencionado como receptor de um passe de LeBron e como contribuidor para a vitória.
# * **Austin Reaves:** Jogador dos Lakers.  Mencionado como tendo um bom desempenho no jogo e contribuindo para a vitória.
# * **D'Angelo Russell:** Jogador dos Lakers. Mencionado como parte da equipe e contribuindo para a vitória.
#
# Entidades envolvidas na URL fornecida:
#
# * **Bruno Henrique:** Jogador do Flamengo
# * **Michael:** Jogador do Flamengo
# * **Dorival Júnior:**  Técnico do Flamengo (mencionado indiretamente, por ser quem define a escalação)
# * **Flamengo:** Time de futebol
# * **Everton Ribeiro:** Jogador do Flamengo
# * **Arrascaeta:** Jogador do Flamengo
# ...

# %% [markdown]
# **R.:** O gemini flash identificou algumas entidades, porém apenas as principais e mais uma vez alucionou um pouco e inventou informações, enquanto que o gemini pro teve um resultado mais consistênte.

# %% [markdown]
# ### 9. Cálculo de Tokens em Texto Longo com API Gemini

# %% [markdown]
# **Enunciado:** Implemente um notebook que use a API Gemini para calcular a quantidade de tokens necessários para processar um texto de 5.000 palavras. Baseie-se no modelo de tokenização utilizado por Gemini e explique como a quantidade de tokens influencia o custo e o desempenho da interação com LLMs em textos longos.

# %%
import google.generativeai as genai
import os

genai.configure(api_key=os.environ["GEMINI_KEY"])

model = genai.GenerativeModel("gemini-1.5-flash")

texto_longo = 'Exemplo rápido de texto longo' * 1000

response = model.generate_content(texto_longo)

print(response.usage_metadata)
# Out:
# prompt_token_count: 5001
# candidates_token_count: 593
# total_token_count: 5594

# %% [markdown]
# **R.:** A maior quantidade de tokens aumenta o processamento a ser realizado pelo modelo, resultando em maior espera pela resposta, maior gasto computacional e energético o que por sua vez aumenta o custo, além disso, os modelos possuem limites na quantidade de tokens que conseguem operar, quando esse limite é ultrapassado o modelo pode perder informações importantes e ter uma resposta fora do esperado.

# %% [markdown]
# ### 10.  Otimização de Respostas com Role Prompting

# %% [markdown]
# **Enunciado:**
# No Poe.com, aplique a técnica de Role Prompting para otimizar as respostas do LLM Claude3.5. O cenário é o seguinte: você está desenvolvendo um assistente virtual para uma empresa de consultoria jurídica. Crie um prompt onde o modelo deve assumir o papel de um advogado especializado em direito contábil ao responder perguntas sobre Imposto de Renda de Pessoa Física. Avalie a resposta do modelo para uma mesma pergunta sobre IRPF num prompt com e sem Role Prompting.

# %% [markdown]
# **R.:** A resposta com definição de papel foi mais assertiva, enquanto que a resposta para prompt simples, apesar de não estar errada, foi menos direta e houve repetição de informações.

# %% [markdown]
# 1. Role Prompting
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Prompt simples
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 11. Estruturação de Prompts com Arquivo YAML

# %% [markdown]
# **Enunciado:**
# Crie um arquivo YAML que represente a estrutura:
# {‘'roteiro’: {‘atenas’: ‘prompt’, ‘roma’: ‘prompt’}},
# onde você deve definir dois prompts: um para listar 3 pontos turísticos de Roma, o número anual de visitantes e uma breve descrição de cada um, e outro para fazer o mesmo com Atenas. Em seguida, crie um notebook que leia esse arquivo YAML e execute os prompts usando o Gemini (uma execução por cidade no roteiro). Qual foi o resultado? Os pontos turísticos são relevantes e suas descrições são precisas?

# %%
import google.generativeai as genai
import os
from google.generativeai.types import HarmCategory, HarmBlockThreshold
import datetime as dt
import yaml

genai.configure(api_key=os.environ["GEMINI_KEY"])

with open('configs/config.yaml','r') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)

system_instruction = 'Você é um agente de viagens que está elaborando pacotes turísticos, '

safety_settings={
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
}

generation_config = genai.types.GenerationConfig(
        candidate_count=1,
        max_output_tokens=500,
        temperature=0.2,
    )

model = genai.GenerativeModel("gemini-1.5-pro"
                              ,system_instruction = system_instruction
                              ,safety_settings=safety_settings
                              ,generation_config=generation_config)

response = model.generate_content(config['roteiro']['roma'])

print(response.text)
# Out:
# ## 3 Pontos Turísticos Imperdíveis em Roma:
#
# **1. Coliseu:**
#
# * **Número anual de visitantes:** Aproximadamente 7,6 milhões (dados pré-pandemia, os números atuais podem variar).
# * **Descrição:** O Coliseu, também conhecido como Anfiteatro Flaviano, é um anfiteatro oval no centro da cidade de Roma, Itália. Construído com concreto e areia, é o maior anfiteatro já construído e é considerado uma das maiores obras da arquitetura e engenharia romana.  Era usado para combates de gladiadores e espetáculos públicos, como caçadas de animais, execuções, reconstituições de batalhas famosas e dramas baseados na mitologia clássica. Uma visita ao Coliseu é uma viagem no tempo, permitindo visualizar a grandiosidade do Império Romano.  Recomenda-se reservar ingressos com antecedência para evitar filas.
#
# **2. Museus Vaticanos:**
#
# * **Número anual de visitantes:** Aproximadamente 6 milhões (dados pré-pandemia, os números atuais podem variar).
# ...

# %%
response = model.generate_content(config['roteiro']['atenas'])

print(response.text)
# Out:
# Claro, aqui estão 3 pontos turísticos em Atenas, juntamente com seu número anual de visitantes e uma breve descrição:
#
# **1. Acrópole**
#
# * **Número anual de visitantes:** ~1.700.000
# * **Descrição:** A Acrópole é uma antiga cidadela localizada em um afloramento rochoso acima de Atenas. Contém os restos de vários edifícios antigos de grande importância arquitetônica e histórica, sendo o mais famoso o Partenon. É um Patrimônio Mundial da UNESCO e um dos marcos mais populares da Grécia.
#
# **2. Museu da Acrópole**
#
# * **Número anual de visitantes:** ~1.600.000
# * **Descrição:** O Museu da Acrópole é um museu arqueológico que abriga artefatos encontrados no sítio arqueológico da Acrópole de Atenas. O museu foi construído para abrigar todos os achados da rocha e das encostas circundantes, desde a era do bronze grego até a Grécia romana e bizantina.
#
# **3. Antiga Ágora de Atenas**
#
# * **Número anual de visitantes:** ~850.000
# ...

# %% [markdown]
# **R.:** O Gemini-1.5-Pro trouxe um bom resultado, trazendo localidades relevantes e com número de visitantes bem próximo dos que foram encontrados em outras fontes.

# %% [markdown]
# ### 12. Sistema de Envio de Emails com Dados Turísticos em JSON
#
# Queremos montar um sistema que envie emails com os pontos turísticos de cidades num roteiro de viagem. Com base no Exercício 11, altere o prompt para estruturar a saída em formato JSON, com descrições e número de visitantes. Crie um notebook que use a biblioteca pandas para converter esse JSON para dataframe e plot um único gráfico de barras horizontais com todos os pontos turísticos, destacando as cores das barras de acordo com a cidade do ponto turístico (Coliseu, em Roma deve ter uma cor diferente que Parthenon, em Atenas). Coloque as legendas no gráfico.

# %%
import google.generativeai as genai
import os
from google.generativeai.types import HarmCategory, HarmBlockThreshold
import datetime as dt
import yaml
import pandas as pd
import json

genai.configure(api_key=os.environ["GEMINI_KEY"])

with open('configs/config.yaml','r') as file:
    config = yaml.load(file, Loader=yaml.FullLoader)

system_instruction = '''Você é um agente de viagens que está elaborando pacotes turísticos, os pacotes devem estar em formato json, conforme o exemplo abaixo:
    {
    "cidade": "Paris",
    "ponto_turistico": "Torre Eiffel",
    "numero_anual_visitantes": 7000000,
    "descricao": " A Torre Eiffel é uma torre treliça de ferro do século XIX localizada no Champ de Mars, em Paris, que se tornou um ícone mundial da França e uma das estruturas mais reconhecidas no mundo. A Torre Eiffel é o monumento pago mais visitado do mundo, com milhões de pessoas subindo à torre a cada ano. Nomeada em homenagem ao engenheiro Gustave Eiffel, cuja empresa projetou e construiu a estrutura.",
    }, não utilize o " ou qualquer outro caracter que prejudique a função json.loads, agora '''

safety_settings={
    HarmCategory.HARM_CATEGORY_HATE_SPEECH: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_HARASSMENT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_SEXUALLY_EXPLICIT: HarmBlockThreshold.BLOCK_NONE,
    HarmCategory.HARM_CATEGORY_DANGEROUS_CONTENT: HarmBlockThreshold.BLOCK_NONE,
}

generation_config = genai.types.GenerationConfig(
        candidate_count=1,
        max_output_tokens=750,
        temperature=0.2,
    )

model = genai.GenerativeModel("gemini-1.5-pro"
                              ,system_instruction = system_instruction
                              ,safety_settings=safety_settings
                              ,generation_config=generation_config)

responseRoma = model.generate_content(config['roteiro']['roma'])

# %%
print(responseRoma.text)
# Out:
# ```json
# [
#     {
#         "cidade": "Roma",
#         "ponto_turistico": "Coliseu",
#         "numero_anual_visitantes": 7600000,
#         "descricao": "O Coliseu é um anfiteatro oval no centro da cidade de Roma, Itália, a leste do Fórum Romano. É a maior estrutura antiga já construída e ainda é o maior anfiteatro permanente do mundo, apesar de estar em ruínas. Sua construção começou sob o imperador Vespasiano por volta de 72 d.C. e foi concluída em 80 d.C. sob seu sucessor e herdeiro Tito."
#     },
#     {
#         "cidade": "Roma",
#         "ponto_turistico": "Museus Vaticanos",
#         "numero_anual_visitantes": 6000000,
# ...

# %%
jRoma = json.loads(responseRoma.text.split('```')[1].replace('json',''))

dfPontos = pd.DataFrame(jRoma)

dfPontos
# Out:
#   cidade   ponto_turistico  numero_anual_visitantes  \
# 0   Roma           Coliseu                  7600000
# 1   Roma  Museus Vaticanos                  6000000
# 2   Roma      Fórum Romano                  4500000
#
#                                            descricao
# 0  O Coliseu é um anfiteatro oval no centro da ci...
# 1  Os Museus Vaticanos são museus cristãos e de a...
# 2  O Fórum Romano, também conhecido por seu nome ...

# %%
responseAtenas = model.generate_content(config['roteiro']['atenas'])

print(responseAtenas.text)
# Out:
# ```json
# [
#     {
#         "cidade": "Atenas",
#         "ponto_turistico": "Acrópole de Atenas",
#         "numero_anual_visitantes": 4000000,
#         "descricao": "A Acrópole de Atenas é uma antiga cidadela localizada em um afloramento rochoso acima da cidade de Atenas e contém os restos de vários edifícios antigos de grande significado arquitetônico e histórico, sendo o mais famoso o Partenon. A palavra acrópole vem do grego para extremidade (ákros) e cidade (pólis)."
#     },
#     {
#         "cidade": "Atenas",
#         "ponto_turistico": "Museu da Acrópole",
#         "numero_anual_visitantes": 2000000,
#         "descricao": "O Museu da Acrópole é um museu arqueológico que abriga muitos dos achados arqueológicos das encostas da Acrópole de Atenas, da própria Acrópole e das encostas circundantes. O museu foi fundado em 2003, enquanto o novo edifício foi concluído em 2009."
#     },
#     {
#         "cidade": "Atenas",
# ...

# %%
jAtenas = json.loads(responseAtenas.text.split('```')[1].replace('json','').strip())

dfPontos = pd.concat([dfPontos, pd.DataFrame(jAtenas)])

# %%
dfPontos
# Out:
#    cidade         ponto_turistico  numero_anual_visitantes  \
# 0    Roma                 Coliseu                  7600000
# 1    Roma        Museus Vaticanos                  6000000
# 2    Roma            Fórum Romano                  4500000
# 0  Atenas      Acrópole de Atenas                  4000000
# 1  Atenas       Museu da Acrópole                  2000000
# 2  Atenas  Antiga Ágora de Atenas                  1000000
#
#                                            descricao
# 0  O Coliseu é um anfiteatro oval no centro da ci...
# 1  Os Museus Vaticanos são museus cristãos e de a...
# 2  O Fórum Romano, também conhecido por seu nome ...
# 0  A Acrópole de Atenas é uma antiga cidadela loc...
# 1  O Museu da Acrópole é um museu arqueológico qu...
# 2  A Antiga Ágora de Atenas é um complexo de ruín...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(x='numero_anual_visitantes', y='ponto_turistico', data=dfPontos, hue='cidade', ax=ax, orient='h') 

#Colocar o eixo x em formato de número, por milhão
ax.get_xaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))

plt.title('Número de visitantes anuais por ponto turístico')
plt.xlabel('Número de visitantes')
plt.ylabel('Ponto turístico')
plt.show()
